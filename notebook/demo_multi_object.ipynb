# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## 1. Imports and Model Loading

# %%
import os
import uuid
import imageio
import numpy as np
from IPython.display import Image as ImageDisplay

from inference import Inference, ready_gaussian_for_video_rendering, load_image, load_masks, display_image, make_scene, render_video, interactive_visualizer
# Out:
# /scratch/cl927/miniconda3/envs/sam3d-objects/lib/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Warp 1.11.0 initialized:
#    CUDA Toolkit 12.9, Driver 12.6
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#      "cuda:1"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#      "cuda:2"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#      "cuda:3"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#      "cuda:4"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#      "cuda:5"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#      "cuda:6"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#      "cuda:7"   : "NVIDIA RTX A5000" (24 GiB, sm_86, mempool enabled)
#    CUDA peer access:
#      Supported fully (all-directional)
#    Kernel cache:
#      /home/mifs/cl927/.cache/warp/1.11.0
# 2026-02-19 22:02:34.458 | INFO     | sam3d_objects.pipeline.inference_pipeline:set_attention_backend:17 - GPU name is NVIDIA RTX A5000
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# 2026-02-19 22:02:35.998 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.sparse:__from_env:39 - [SPARSE] Backend: spconv, Attention: sdpa
# 2026-02-19 22:02:40.468 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.attention:__from_env:30 - [ATTENTION] Using backend: sdpa
# [SPARSE][CONV] spconv algo: auto
# 2026-02-19 22:02:41.683 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-02-19 22:02:41.684 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift

# %%
PATH = os.getcwd()
TAG = "hf"
config_path = f"{PATH}/../checkpoints/{TAG}/pipeline.yaml"
inference = Inference(config_path, compile=False)
# Out:
# 2026-02-19 22:02:41.752 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# /scratch/cl927/miniconda3/envs/sam3d-objects/lib/python3.11/site-packages/moge/model/v1.py:171: UserWarning: The following deprecated/invalid arguments are ignored: {'output_mask': True, 'split_head': True}
#   warnings.warn(f"The following deprecated/invalid arguments are ignored: {deprecated_kwargs}")
# 2026-02-19 22:02:52.562 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-02-19 22:02:52.564 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:100 - self.device: cuda
# 2026-02-19 22:02:52.565 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:101 - CUDA_VISIBLE_DEVICES: None
# 2026-02-19 22:02:52.566 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:102 - Actually using GPU: 0
# 2026-02-19 22:02:52.566 | INFO     | sam3d_objects.pipeline.inference_pipeline:init_pose_decoder:297 - Using pose decoder: ScaleShiftInvariant
# 2026-02-19 22:02:52.567 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:133 - Loading model weights...
# 2026-02-19 22:02:52.820 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/ss_generator.ckpt
# 2026-02-19 22:03:02.311 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/slat_generator.ckpt
# 2026-02-19 22:03:05.090 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/ss_decoder.ckpt
# 2026-02-19 22:03:05.274 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/slat_decoder_gs.ckpt
# 2026-02-19 22:03:05.459 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/slat_decoder_gs_4.ckpt
# 2026-02-19 22:03:05.616 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/slat_decoder_mesh.ckpt
# 2026-02-19 22:03:05.845 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-02-19 22:03:06.790 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-02-19 22:03:06.795 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-02-19 22:03:07.144 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-02-19 22:03:07.164 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/ss_generator.ckpt
# 2026-02-19 22:03:09.892 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-02-19 22:03:10.231 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-02-19 22:03:10.237 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-02-19 22:03:10.574 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-02-19 22:03:10.583 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from /scratch/cl927/sam-3d-objects/notebook/../checkpoints/hf/slat_generator.ckpt
# 2026-02-19 22:03:12.036 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_ss_generator_cfg_config:438 - ss_generator parameters: inference_steps=25, cfg_strength=7, cfg_interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-02-19 22:03:12.038 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_slat_generator_cfg_config:460 - slat_generator parameters: inference_steps=25, cfg_strength=1, cfg_interval=[0, 500], rescale_t=1
# 2026-02-19 22:03:12.039 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:198 - Loading model weights completed!

# %% [markdown]
# ## 2. Load input image to lift to 3D (multiple objects)

# %%
IMAGE_PATH = f"{PATH}/images/shutterstock_stylish_kidsroom_1640806567/image.png"
IMAGE_NAME = os.path.basename(os.path.dirname(IMAGE_PATH))

image = load_image(IMAGE_PATH)
# masks = load_masks(os.path.dirname(IMAGE_PATH), extension=".png")
masks = load_masks(os.path.dirname(IMAGE_PATH), indices_list=[0,5,6], extension=".png")
display_image(image, masks)

# %% [markdown]
# ## 3. Generate Gaussian Splats

# %%
import torch
torch.cuda.empty_cache()

# %%
# outputs = [inference(image, mask, seed=42) for mask in masks]
outputs = []
for mask in masks:
    output = inference(image, mask, seed=42)
    outputs.append(output)

    # Clear cache after each inference to prevent OOM errors
    torch.cuda.empty_cache()
# Out:
# 2026-02-19 22:03:22.968 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:664 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-02-19 22:03:22.972 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:633 - Running condition embedder ...
# 2026-02-19 22:03:23.102 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Condition embedder finishes!
# 2026-02-19 22:03:31.153 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:714 - Downsampled coords from 32333 to 29028
# 2026-02-19 22:03:31.185 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:437 - Rescaling scale by 1 after downsampling
# 2026-02-19 22:03:31.186 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:746 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2026-02-19 22:03:31.187 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:633 - Running condition embedder ...
# 2026-02-19 22:03:31.281 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Condition embedder finishes!
# 2026-02-19 22:03:50.965 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:606 - Decoding sparse latent...
# 2026-02-19 22:04:24.846 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:540 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2026-02-19 22:04:24.899 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:502 - Finished!
# 2026-02-19 22:04:28.018 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:664 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-02-19 22:04:28.023 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:633 - Running condition embedder ...
# 2026-02-19 22:04:28.143 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Condition embedder finishes!
# 2026-02-19 22:04:36.318 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:714 - Downsampled coords from 20481 to 20290
# 2026-02-19 22:04:36.327 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:437 - Rescaling scale by 1 after downsampling
# 2026-02-19 22:04:36.328 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:746 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2026-02-19 22:04:36.331 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:633 - Running condition embedder ...
# 2026-02-19 22:04:36.428 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Condition embedder finishes!
# 2026-02-19 22:04:47.940 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:606 - Decoding sparse latent...
# 2026-02-19 22:04:49.620 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:540 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2026-02-19 22:04:49.645 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:502 - Finished!
# 2026-02-19 22:04:52.518 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:664 - Sampling sparse structure: inference_steps=25, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-02-19 22:04:52.519 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:633 - Running condition embedder ...
# 2026-02-19 22:04:52.633 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Condition embedder finishes!
# 2026-02-19 22:05:00.793 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:714 - Downsampled coords from 3570 to 3570
# 2026-02-19 22:05:00.801 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:437 - Rescaling scale by 1 after downsampling
# 2026-02-19 22:05:00.801 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:746 - Sampling sparse latent: inference_steps=25, strength=1, interval=[0, 500], rescale_t=1
# 2026-02-19 22:05:00.802 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:633 - Running condition embedder ...
# 2026-02-19 22:05:00.890 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Condition embedder finishes!
# 2026-02-19 22:05:04.126 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:606 - Decoding sparse latent...
# 2026-02-19 22:05:04.276 | INFO     | sam3d_objects.pipeline.inference_pipeline:postprocess_slat_output:540 - Postprocessing mesh with option with_mesh_postprocess False, with_texture_baking False...
# 2026-02-19 22:05:04.280 | INFO     | sam3d_objects.pipeline.inference_pipeline_pointmap:run:502 - Finished!

# %% [markdown]
# ## 4. Visualize Gaussian Splat of the Scene
# ### a. Animated Gif

# %%
scene_gs = make_scene(*outputs)
# export posed gaussian splatting (as point cloud)
scene_gs.save_ply(f"{PATH}/gaussians/{IMAGE_NAME}_posed.ply")

scene_gs = ready_gaussian_for_video_rendering(scene_gs)
# export gaussian splatting (as point cloud)
scene_gs.save_ply(f"{PATH}/gaussians/multi/{IMAGE_NAME}.ply")

video = render_video(
    scene_gs,
    r=1,
    fov=60,
    resolution=512,
)["color"]

# save video as gif
imageio.mimsave(
    os.path.join(f"{PATH}/gaussians/multi/{IMAGE_NAME}.gif"),
    video,
    format="GIF",
    duration=1000 / 30,  # default assuming 30fps from the input MP4
    loop=0,  # 0 means loop indefinitely
)

# notebook display
ImageDisplay(url=f"gaussians/multi/{IMAGE_NAME}.gif?cache_invalidator={uuid.uuid4()}",)
# Out:
# Rendering: 300it [00:08, 34.87it/s]
# <img src="gaussians/multi/shutterstock_stylish_kidsroom_1640806567.gif?cache_invalidator=c8e953bb-6be7-4dd4-bb6c-e54af05851c0"/>

# %% [markdown]
# ### b. Interactive Visualizer

# %%
# might take a while to load (black screen)
interactive_visualizer(f"{PATH}/gaussians/multi/{IMAGE_NAME}.ply")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 # might take a while to load (black screen)
# ----> 2 interactive_visualizer(f"{PATH}/gaussians/multi/{IMAGE_NAME}.ply")
#
# File /scratch/cl927/sam-3d-objects/notebook/inference.py:413, in interactive_visualizer(ply_path)
#     412 def interactive_visualizer(ply_path):
# --> 413     with gr.Blocks() as demo:
#     414         gr.Markdown("# 3D Gaussian Splatting (black-screen loading might take a while)")
#     415         gr.Model3D(
#     416             value=ply_path,  # splat file
#     417             label="3D Scene",
#     418         )
#
# File /scratch/cl927/miniconda3/envs/sam3d-objects/lib/python3.11/site-packages/gradio/blocks.py:1179, in Blocks.__init__(self, theme, analytics_enabled, mode, title, css, css_paths, js, head, head_paths, fill_height, fill_width, delete_cache, **kwargs)
#    1175     analytics.initiated_analytics(data)
#    1177 Blocks.instances.add(self)
# -> 1179 self.queue()
#
# File /scratch/cl927/miniconda3/envs/sam3d-objects/lib/python3.11/site-packages/gradio/blocks.py:2365, in Blocks.queue(self, status_update_rate, api_open, max_size, default_concurrency_limit)
#    2356     max_size = 1 if max_size is None else max_size
#    2357 self._queue = queueing.Queue(
#    2358     live_updates=status_update_rate == "auto",
#    2359     concurrency_count=self.max_threads,
#    (...)   2363     default_concurrency_limit=default_concurrency_limit,
#    2364 )
# -> 2365 self.app = App.create_app(self, mcp_server=False)
#    2366 return self
#
# File /scratch/cl927/miniconda3/envs/sam3d-objects/lib/python3.11/site-packages/gradio/routes.py:1987, in App.create_app(blocks, app_kwargs, auth_dependency, strict_cors, ssr_mode, mcp_server)
#    1979         return FileResponse(
#    1980             input_path,
#    1981             media_type="video/mp4",
#    1982             filename="gradio-screen-recording.mp4",
#    1983             background=BackgroundTask(lambda: cleanup_files([input_path])),
#    1984         )
#    1986 vibe_edit_history_dir = Path(DEFAULT_TEMP_DIR) / "vibe_edit_history"
# -> 1987 vibe_edit_history_dir.mkdir(exist_ok=True, parents=True)
#    1988 chat_history = {"history": ""}
#    1989 hash_to_chat_history = {}
#
# File /scratch/cl927/miniconda3/envs/sam3d-objects/lib/python3.11/pathlib.py:1116, in Path.mkdir(self, mode, parents, exist_ok)
#    1112 """
#    1113 Create a new directory at this given path.
#    1114 """
#    1115 try:
# -> 1116     os.mkdir(self, mode)
#    1117 except FileNotFoundError:
#    1118     if not parents or self.parent == self:
#
# PermissionError: [Errno 13] Permission denied: '/tmp/gradio/vibe_edit_history'
